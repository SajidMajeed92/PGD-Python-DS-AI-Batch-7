# %%
import pandas as pd
import numpy as np

# Generating sample Google Play Store data
data = {
    'App': [f'App_{i}' for i in range(1, 31)],
    'Category': np.random.choice(['Game', 'Productivity', 'Health', 'Education'], 30),
    'Rating': np.random.uniform(1.0, 5.0, 30).round(1),
    'Reviews': np.random.randint(1, 10000, 30),
    'Size': np.random.choice(['Varies with device', '10M', '20M', '30M'], 30),
    'Installs': np.random.choice(['1,000+', '10,000+', '50,000+', '100,000+'], 30),
    'Type': np.random.choice(['Free', 'Paid'], 30),
    'Price': np.random.choice(['0', '0.99', '1.99', '2.99', '4.99', '5.99', '9.99'], 30),
    'Content Rating': np.random.choice(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+'], 30)
}

# %%
data
# Out:
# {'App': ['App_1',
#   'App_2',
#   'App_3',
#   'App_4',
#   'App_5',
#   'App_6',
#   'App_7',
#   'App_8',
#   'App_9',
#   'App_10',
#   'App_11',
#   'App_12',
#   'App_13',
#   'App_14',
#   'App_15',
#   'App_16',
#   'App_17',
#   'App_18',
#   'App_19',
#   'App_20',
#   'App_21',
#   'App_22',
#   'App_23',
#   'App_24',
#   'App_25',
#   'App_26',
#   'App_27',
#   'App_28',
#   'App_29',
#   'App_30'],
#  'Category': array(['Game', 'Education', 'Education', 'Game', 'Game', 'Game',
#         'Productivity', 'Productivity', 'Education', 'Health', 'Health',
#         'Education', 'Game', 'Game', 'Game', 'Productivity', 'Health',
#         'Productivity', 'Education', 'Game', 'Game', 'Education',
#         'Education', 'Productivity', 'Game', 'Health', 'Education', 'Game',
#         'Education', 'Game'], dtype='<U12'),
#  'Rating': array([1.7, 1.7, 3.4, 3.7, 2.9, 2.8, 3.3, 1.9, 2.5, 2.9, 4.2, 3.2, 2.5,
#         3.5, 1.8, 1.1, 2.7, 2.7, 2.6, 1.6, 1.2, 2. , 4.6, 2.2, 2.9, 2.6,
#         2.7, 1.7, 1.6, 3.6]),
#  'Reviews': array([8221, 4652, 8219, 1423, 3718, 3868, 3868, 2914, 2314, 8791,  675,
#         3385, 8741, 7784, 8950, 2621, 6651, 7372, 2906, 7468, 8542, 8328,
#         5516, 1030,  657, 5633, 6520, 3374, 8761, 5388]),
#  'Size': array(['Varies with device', '20M', '20M', 'Varies with device', '30M',
#         '20M', 'Varies with device', 'Varies with device', '30M', '20M',
#         '20M', '20M', '30M', '30M', '30M', '30M', 'Varies with device',
#         'Varies with device', '30M', '20M', '10M', '20M', '10M',
#         'Varies with device', '20M', '10M', 'Varies with device', '20M',
#         '20M', '30M'], dtype='<U18'),
#  'Installs': array(['100,000+', '50,000+', '50,000+', '10,000+', '50,000+', '10,000+',
#         '1,000+', '100,000+', '1,000+', '100,000+', '1,000+', '10,000+',
#         '100,000+', '50,000+', '50,000+', '50,000+', '10,000+', '1,000+',
#         '100,000+', '100,000+', '50,000+', '100,000+', '50,000+',
#         '100,000+', '100,000+', '1,000+', '100,000+', '50,000+', '1,000+',
#         '1,000+'], dtype='<U8'),
#  'Type': array(['Paid', 'Paid', 'Paid', 'Paid', 'Paid', 'Free', 'Paid', 'Free',
#         'Free', 'Free', 'Paid', 'Paid', 'Paid', 'Paid', 'Free', 'Free',
#         'Free', 'Free', 'Paid', 'Paid', 'Paid', 'Paid', 'Paid', 'Free',
#         'Paid', 'Free', 'Paid', 'Paid', 'Free', 'Free'], dtype='<U4'),
#  'Price': array(['5.99', '2.99', '0.99', '0', '1.99', '5.99', '0.99', '4.99',
#         '9.99', '0.99', '4.99', '5.99', '9.99', '0', '2.99', '1.99',
#         '2.99', '4.99', '0.99', '9.99', '4.99', '0.99', '5.99', '5.99',
#         '5.99', '0.99', '5.99', '9.99', '9.99', '4.99'], dtype='<U4'),
#  'Content Rating': array(['Everyone 10+', 'Everyone', 'Mature 17+', 'Teen', 'Mature 17+',
#         'Mature 17+', 'Teen', 'Everyone', 'Teen', 'Everyone 10+',
#         'Mature 17+', 'Mature 17+', 'Everyone 10+', 'Everyone', 'Teen',
#         'Teen', 'Teen', 'Everyone', 'Everyone 10+', 'Everyone', 'Everyone',
#         'Everyone', 'Everyone', 'Everyone 10+', 'Mature 17+', 'Teen',
#         'Everyone 10+', 'Everyone 10+', 'Everyone 10+', 'Mature 17+'],
#        dtype='<U12')}

# %%
type(data)
# Out:
# dict

# %%
# Creating DataFrame
df = pd.DataFrame(data)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#      App   Category  Rating  Reviews                Size  Installs  Type  \
# 0  App_1       Game     1.7     8221  Varies with device  100,000+  Paid
# 1  App_2  Education     1.7     4652                 20M   50,000+  Paid
# 2  App_3  Education     3.4     8219                 20M   50,000+  Paid
# 3  App_4       Game     3.7     1423  Varies with device   10,000+  Paid
# 4  App_5       Game     2.9     3718                 30M   50,000+  Paid
#
#   Price Content Rating
# 0  5.99   Everyone 10+
# 1  2.99       Everyone
# 2  0.99     Mature 17+
# 3     0           Teen
# 4  1.99     Mature 17+

# %%
df.tail()
# Out:
#        App   Category  Rating  Reviews                Size  Installs  Type  \
# 25  App_26     Health     2.6     5633                 10M    1,000+  Free
# 26  App_27  Education     2.7     6520  Varies with device  100,000+  Paid
# 27  App_28       Game     1.7     3374                 20M   50,000+  Paid
# 28  App_29  Education     1.6     8761                 20M    1,000+  Free
# 29  App_30       Game     3.6     5388                 30M    1,000+  Free
#
#    Price Content Rating
# 25  0.99           Teen
# 26  5.99   Everyone 10+
# 27  9.99   Everyone 10+
# 28  9.99   Everyone 10+
# 29  4.99     Mature 17+

# %%
# !pip install module name

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 9)

# %%
df['Category'].unique()
# Out:
# array(['Game', 'Education', 'Productivity', 'Health'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             30 non-null     object
#  1   Category        30 non-null     object
#  2   Rating          30 non-null     float64
#  3   Reviews         30 non-null     int32
#  4   Size            30 non-null     object
#  5   Installs        30 non-null     object
#  6   Type            30 non-null     object
#  7   Price           30 non-null     object
#  8   Content Rating  30 non-null     object
# dtypes: float64(1), int32(1), object(7)
# memory usage: 2.1+ KB

# %%
df.sample(4)
# Out:
#        App      Category  Rating  Reviews                Size  Installs  Type  \
# 10  App_11        Health     4.2      675                 20M    1,000+  Paid
# 29  App_30          Game     3.6     5388                 30M    1,000+  Free
# 7    App_8  Productivity     1.9     2914  Varies with device  100,000+  Free
# 22  App_23     Education     4.6     5516                 10M   50,000+  Paid
#
#    Price Content Rating
# 10  4.99     Mature 17+
# 29  4.99     Mature 17+
# 7   4.99       Everyone
# 22  5.99       Everyone

# %%
df.isnull()
# Out:
#       App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0   False     False   False    False  False     False  False  False
# 1   False     False   False    False  False     False  False  False
# 2   False     False   False    False  False     False  False  False
# 3   False     False   False    False  False     False  False  False
# 4   False     False   False    False  False     False  False  False
# 5   False     False   False    False  False     False  False  False
# 6   False     False   False    False  False     False  False  False
# 7   False     False   False    False  False     False  False  False
# 8   False     False   False    False  False     False  False  False
# 9   False     False   False    False  False     False  False  False
# 10  False     False   False    False  False     False  False  False
# 11  False     False   False    False  False     False  False  False
# 12  False     False   False    False  False     False  False  False
# 13  False     False   False    False  False     False  False  False
# 14  False     False   False    False  False     False  False  False
# 15  False     False   False    False  False     False  False  False
# 16  False     False   False    False  False     False  False  False
# 17  False     False   False    False  False     False  False  False
# 18  False     False   False    False  False     False  False  False
# 19  False     False   False    False  False     False  False  False
# 20  False     False   False    False  False     False  False  False
# 21  False     False   False    False  False     False  False  False
# 22  False     False   False    False  False     False  False  False
# 23  False     False   False    False  False     False  False  False
# 24  False     False   False    False  False     False  False  False
# 25  False     False   False    False  False     False  False  False
# 26  False     False   False    False  False     False  False  False
# 27  False     False   False    False  False     False  False  False
# 28  False     False   False    False  False     False  False  False
# 29  False     False   False    False  False     False  False  False
#
#     Content Rating
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# 5            False
# 6            False
# 7            False
# 8            False
# 9            False
# 10           False
# 11           False
# 12           False
# 13           False
# 14           False
# 15           False
# 16           False
# 17           False
# 18           False
# 19           False
# 20           False
# 21           False
# 22           False
# 23           False
# 24           False
# 25           False
# 26           False
# 27           False
# 28           False
# 29           False

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# dtype: int64

# %%
# Basic data cleansing
# Step 1: Convert 'Price' to numeric, replacing '$' and converting 'Free' to 0
df['Price'] = df['Price'].replace('Free', '0')

# %%
type(df['Price'])
# Out:
# pandas.core.series.Series

# %%
df['Price'] = df['Price'].str.replace('$', '').astype(float)
# Out:
# <ipython-input-18-3d1d9481e45a>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Price'] = df['Price'].str.replace('$', '').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             30 non-null     object
#  1   Category        30 non-null     object
#  2   Rating          30 non-null     float64
#  3   Reviews         30 non-null     int32
#  4   Size            30 non-null     object
#  5   Installs        30 non-null     object
#  6   Type            30 non-null     object
#  7   Price           30 non-null     float64
#  8   Content Rating  30 non-null     object
# dtypes: float64(2), int32(1), object(6)
# memory usage: 2.1+ KB

# %%
df.head()
# Out:
#      App   Category  Rating  Reviews                Size  Installs  Type  \
# 0  App_1       Game     1.7     8221  Varies with device  100,000+  Paid
# 1  App_2  Education     1.7     4652                 20M   50,000+  Paid
# 2  App_3  Education     3.4     8219                 20M   50,000+  Paid
# 3  App_4       Game     3.7     1423  Varies with device   10,000+  Paid
# 4  App_5       Game     2.9     3718                 30M   50,000+  Paid
#
#    Price Content Rating
# 0   5.99   Everyone 10+
# 1   2.99       Everyone
# 2   0.99     Mature 17+
# 3   0.00           Teen
# 4   1.99     Mature 17+

# %%
# Additional Steps
# Step 2: Remove duplicates based on the 'App' column
df = df.drop_duplicates(subset=['App'])

# %%
# Step 3: Fill missing values in 'Rating' with the mean rating
df['Rating'] = df['Rating'].fillna(df['Rating'].mean())

# %%
# Step 4: Normalize the 'Reviews' column (scaling between 0 and 1)
df['Reviews'] = (df['Reviews'] - df['Reviews'].min()) / (df['Reviews'].max() - df['Reviews'].min())

# %%
df['Size'].unique()
# Out:
# array(['Varies with device', '20M', '30M', '10M'], dtype=object)

# %%
df.head()
# Out:
#      App   Category  Rating   Reviews                Size  Installs  Type  \
# 0  App_1       Game     1.7  0.912095  Varies with device  100,000+  Paid
# 1  App_2  Education     1.7  0.481732                 20M   50,000+  Paid
# 2  App_3  Education     3.4  0.911853                 20M   50,000+  Paid
# 3  App_4       Game     3.7  0.092367  Varies with device   10,000+  Paid
# 4  App_5       Game     2.9  0.369106                 30M   50,000+  Paid
#
#    Price Content Rating
# 0   5.99   Everyone 10+
# 1   2.99       Everyone
# 2   0.99     Mature 17+
# 3   0.00           Teen
# 4   1.99     Mature 17+

# %%
# Step 5: Simplify 'Size' column (replace 'Varies with device' with NaN)
df['Size'] = df['Size'].replace('Varies with device', np.nan)

# %%
df.head()
# Out:
#      App   Category  Rating   Reviews Size  Installs  Type  Price  \
# 0  App_1       Game     1.7  0.912095  NaN  100,000+  Paid   5.99
# 1  App_2  Education     1.7  0.481732  20M   50,000+  Paid   2.99
# 2  App_3  Education     3.4  0.911853  20M   50,000+  Paid   0.99
# 3  App_4       Game     3.7  0.092367  NaN   10,000+  Paid   0.00
# 4  App_5       Game     2.9  0.369106  30M   50,000+  Paid   1.99
#
#   Content Rating
# 0   Everyone 10+
# 1       Everyone
# 2     Mature 17+
# 3           Teen
# 4     Mature 17+

# %%
df.head()
# Out:
#      App   Category  Rating   Reviews Size  Installs  Type  Price  \
# 0  App_1       Game     1.7  0.912095  NaN  100,000+  Paid   5.99
# 1  App_2  Education     1.7  0.481732  20M   50,000+  Paid   2.99
# 2  App_3  Education     3.4  0.911853  20M   50,000+  Paid   0.99
# 3  App_4       Game     3.7  0.092367  NaN   10,000+  Paid   0.00
# 4  App_5       Game     2.9  0.369106  30M   50,000+  Paid   1.99
#
#   Content Rating
# 0   Everyone 10+
# 1       Everyone
# 2     Mature 17+
# 3           Teen
# 4     Mature 17+

# %%
df['Size']
# Out:
# 0     NaN
# 1     20M
# 2     20M
# 3     NaN
# 4     30M
# 5     20M
# 6     NaN
# 7     NaN
# 8     30M
# 9     20M
# 10    20M
# 11    20M
# 12    30M
# 13    30M
# 14    30M
# 15    30M
# 16    NaN
# 17    NaN
# 18    30M
# 19    20M
# 20    10M
# 21    20M
# 22    10M
# 23    NaN
# 24    20M
# 25    10M
# 26    NaN
# 27    20M
# 28    20M
# 29    30M
# Name: Size, dtype: object

# %%
# Step 6: Convert 'Size' from string to numeric (assume 'M' means MB)
df['Size'] = df['Size'].str.replace('M', '').astype(float)

# %%
df.head()
# Out:
#      App   Category  Rating   Reviews  Size  Installs  Type  Price  \
# 0  App_1       Game     1.7  0.912095   NaN  100,000+  Paid   5.99
# 1  App_2  Education     1.7  0.481732  20.0   50,000+  Paid   2.99
# 2  App_3  Education     3.4  0.911853  20.0   50,000+  Paid   0.99
# 3  App_4       Game     3.7  0.092367   NaN   10,000+  Paid   0.00
# 4  App_5       Game     2.9  0.369106  30.0   50,000+  Paid   1.99
#
#   Content Rating
# 0   Everyone 10+
# 1       Everyone
# 2     Mature 17+
# 3           Teen
# 4     Mature 17+

# %%
df['Size']
# Out:
# 0      NaN
# 1     20.0
# 2     20.0
# 3      NaN
# 4     30.0
# 5     20.0
# 6      NaN
# 7      NaN
# 8     30.0
# 9     20.0
# 10    20.0
# 11    20.0
# 12    30.0
# 13    30.0
# 14    30.0
# 15    30.0
# 16     NaN
# 17     NaN
# 18    30.0
# 19    20.0
# 20    10.0
# 21    20.0
# 22    10.0
# 23     NaN
# 24    20.0
# 25    10.0
# 26     NaN
# 27    20.0
# 28    20.0
# 29    30.0
# Name: Size, dtype: float64

# %%
# Step 7: Fill missing values in 'Size' with the median size
df['Size'] = df['Size'].fillna(df['Size'].median())

# %%
df.head()
# Out:
#      App   Category  Rating   Reviews  Size  Installs  Type  Price  \
# 0  App_1       Game     1.7  0.912095  20.0  100,000+  Paid   5.99
# 1  App_2  Education     1.7  0.481732  20.0   50,000+  Paid   2.99
# 2  App_3  Education     3.4  0.911853  20.0   50,000+  Paid   0.99
# 3  App_4       Game     3.7  0.092367  20.0   10,000+  Paid   0.00
# 4  App_5       Game     2.9  0.369106  30.0   50,000+  Paid   1.99
#
#   Content Rating
# 0   Everyone 10+
# 1       Everyone
# 2     Mature 17+
# 3           Teen
# 4     Mature 17+

# %%
# Step 8: Clean 'Installs' column (remove '+' and ',')
df['Installs'] = df['Installs'].str.replace(',', '').str.replace('+', '').astype(int)
# Out:
# <ipython-input-35-91f565401ee9>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Installs'] = df['Installs'].str.replace(',', '').str.replace('+', '').astype(int)

# %%
df['Size']
# Out:
# 0     20.0
# 1     20.0
# 2     20.0
# 3     20.0
# 4     30.0
# 5     20.0
# 6     20.0
# 7     20.0
# 8     30.0
# 9     20.0
# 10    20.0
# 11    20.0
# 12    30.0
# 13    30.0
# 14    30.0
# 15    30.0
# 16    20.0
# 17    20.0
# 18    30.0
# 19    20.0
# 20    10.0
# 21    20.0
# 22    10.0
# 23    20.0
# 24    20.0
# 25    10.0
# 26    20.0
# 27    20.0
# 28    20.0
# 29    30.0
# Name: Size, dtype: float64

# %%
# Step 11: Create a new column 'Popularity' based on 'Rating' and 'Reviews'
df['Popularity'] = df['Rating'] * df['Reviews']

# %%
df.sort_values(by=['Popularity','Size'], ascending=False)
# Out:
#        App      Category  Rating   Reviews  Size  Installs  Type  Price  \
# 2    App_3     Education     3.4  0.911853  20.0     50000  Paid   0.99
# 13  App_14          Game     3.5  0.859399  30.0     50000  Paid   0.00
# 9   App_10        Health     2.9  0.980827  20.0    100000  Free   0.99
# 22  App_23     Education     4.6  0.585916  10.0     50000  Paid   5.99
# 12  App_13          Game     2.5  0.974798  30.0    100000  Paid   9.99
# 17  App_18  Productivity     2.7  0.809719  20.0      1000  Free   4.99
# 29  App_30          Game     3.6  0.570481  30.0      1000  Free   4.99
# 16  App_17        Health     2.7  0.722778  20.0     10000  Free   2.99
# 26  App_27     Education     2.7  0.706982  20.0    100000  Paid   5.99
# 21  App_22     Education     2.0  0.924997  20.0    100000  Paid   0.99
# 14  App_15          Game     1.8  1.000000  30.0     50000  Free   2.99
# 28  App_29     Education     1.6  0.977210  20.0      1000  Free   9.99
# 25  App_26        Health     2.6  0.600024  10.0      1000  Free   0.99
# 0    App_1          Game     1.7  0.912095  20.0    100000  Paid   5.99
# 19  App_20          Game     1.6  0.821295  20.0    100000  Paid   9.99
# 6    App_7  Productivity     3.3  0.387194  20.0      1000  Paid   0.99
# 20  App_21          Game     1.2  0.950802  10.0     50000  Paid   4.99
# 5    App_6          Game     2.8  0.387194  20.0     10000  Free   5.99
# 4    App_5          Game     2.9  0.369106  30.0     50000  Paid   1.99
# 11  App_12     Education     3.2  0.328952  20.0     10000  Paid   5.99
# 1    App_2     Education     1.7  0.481732  20.0     50000  Paid   2.99
# 18  App_19     Education     2.6  0.271193  30.0    100000  Paid   0.99
# 27  App_28          Game     1.7  0.327626  20.0     50000  Paid   9.99
# 7    App_8  Productivity     1.9  0.272157  20.0    100000  Free   4.99
# 8    App_9     Education     2.5  0.199807  30.0      1000  Free   9.99
# 3    App_4          Game     3.7  0.092367  20.0     10000  Paid   0.00
# 15  App_16  Productivity     1.1  0.236826  30.0     50000  Free   1.99
# 23  App_24  Productivity     2.2  0.044978  20.0    100000  Free   5.99
# 10  App_11        Health     4.2  0.002171  20.0      1000  Paid   4.99
# 24  App_25          Game     2.9  0.000000  20.0    100000  Paid   5.99
#
#    Content Rating  Popularity
# 2      Mature 17+    3.100301
# 13       Everyone    3.007898
# 9    Everyone 10+    2.844399
# 22       Everyone    2.695213
# 12   Everyone 10+    2.436995
# 17       Everyone    2.186241
# 29     Mature 17+    2.053732
# 16           Teen    1.951501
# 26   Everyone 10+    1.908851
# 21       Everyone    1.849994
# 14           Teen    1.800000
# 28   Everyone 10+    1.563536
# 25           Teen    1.560063
# 0    Everyone 10+    1.550561
# 19       Everyone    1.314072
# 6            Teen    1.277740
# 20       Everyone    1.140962
# 5      Mature 17+    1.084143
# 4      Mature 17+    1.070409
# 11     Mature 17+    1.052647
# 1        Everyone    0.818944
# 18   Everyone 10+    0.705101
# 27   Everyone 10+    0.556964
# 7        Everyone    0.517099
# 8            Teen    0.499518
# 3            Teen    0.341758
# 15           Teen    0.260509
# 23   Everyone 10+    0.098951
# 10     Mature 17+    0.009116
# 24     Mature 17+    0.000000

# %%
df.head()
# Out:
#      App   Category  Rating   Reviews  Size  Installs  Type  Price  \
# 0  App_1       Game     1.7  0.912095  20.0    100000  Paid   5.99
# 1  App_2  Education     1.7  0.481732  20.0     50000  Paid   2.99
# 2  App_3  Education     3.4  0.911853  20.0     50000  Paid   0.99
# 3  App_4       Game     3.7  0.092367  20.0     10000  Paid   0.00
# 4  App_5       Game     2.9  0.369106  30.0     50000  Paid   1.99
#
#   Content Rating  Popularity
# 0   Everyone 10+    1.550561
# 1       Everyone    0.818944
# 2     Mature 17+    3.100301
# 3           Teen    0.341758
# 4     Mature 17+    1.070409

# %%
df[df['App']=="App_1"]
# Out:
#      App Category  Rating   Reviews  Size  Installs  Type  Price  \
# 0  App_1     Game     1.7  0.912095  20.0    100000  Paid   5.99
#
#   Content Rating  Popularity
# 0   Everyone 10+    1.550561

# %%
len(df[(df['Type'] == 'Paid') & (df['Price'] < 2.00)])
# Out:
# 7

# %%
# Check and categorize paid apps
df['Affordable'] = np.where(df['Type'] == 'Paid', np.where(df['Price'] < 5.00, 'Yes', 'No'), 'N/A')

# %%
# Display the DataFrame
print(df)
# Out:
#        App      Category  Rating   Reviews  Size  Installs  Type  Price  \
# 0    App_1          Game     1.7  0.912095  20.0    100000  Paid   5.99
# 1    App_2     Education     1.7  0.481732  20.0     50000  Paid   2.99
# 2    App_3     Education     3.4  0.911853  20.0     50000  Paid   0.99
# 3    App_4          Game     3.7  0.092367  20.0     10000  Paid   0.00
# 4    App_5          Game     2.9  0.369106  30.0     50000  Paid   1.99
# 5    App_6          Game     2.8  0.387194  20.0     10000  Free   5.99
# 6    App_7  Productivity     3.3  0.387194  20.0      1000  Paid   0.99
# 7    App_8  Productivity     1.9  0.272157  20.0    100000  Free   4.99
# 8    App_9     Education     2.5  0.199807  30.0      1000  Free   9.99
# 9   App_10        Health     2.9  0.980827  20.0    100000  Free   0.99
# 10  App_11        Health     4.2  0.002171  20.0      1000  Paid   4.99
# 11  App_12     Education     3.2  0.328952  20.0     10000  Paid   5.99
# 12  App_13          Game     2.5  0.974798  30.0    100000  Paid   9.99
# 13  App_14          Game     3.5  0.859399  30.0     50000  Paid   0.00
# 14  App_15          Game     1.8  1.000000  30.0     50000  Free   2.99
# 15  App_16  Productivity     1.1  0.236826  30.0     50000  Free   1.99
# 16  App_17        Health     2.7  0.722778  20.0     10000  Free   2.99
# 17  App_18  Productivity     2.7  0.809719  20.0      1000  Free   4.99
# 18  App_19     Education     2.6  0.271193  30.0    100000  Paid   0.99
# 19  App_20          Game     1.6  0.821295  20.0    100000  Paid   9.99
# 20  App_21          Game     1.2  0.950802  10.0     50000  Paid   4.99
# 21  App_22     Education     2.0  0.924997  20.0    100000  Paid   0.99
# 22  App_23     Education     4.6  0.585916  10.0     50000  Paid   5.99
# 23  App_24  Productivity     2.2  0.044978  20.0    100000  Free   5.99
# 24  App_25          Game     2.9  0.000000  20.0    100000  Paid   5.99
# 25  App_26        Health     2.6  0.600024  10.0      1000  Free   0.99
# 26  App_27     Education     2.7  0.706982  20.0    100000  Paid   5.99
# 27  App_28          Game     1.7  0.327626  20.0     50000  Paid   9.99
# 28  App_29     Education     1.6  0.977210  20.0      1000  Free   9.99
# 29  App_30          Game     3.6  0.570481  30.0      1000  Free   4.99
#
#    Content Rating  Popularity Affordable
# 0    Everyone 10+    1.550561         No
# 1        Everyone    0.818944        Yes
# 2      Mature 17+    3.100301        Yes
# 3            Teen    0.341758        Yes
# 4      Mature 17+    1.070409        Yes
# 5      Mature 17+    1.084143        N/A
# 6            Teen    1.277740        Yes
# 7        Everyone    0.517099        N/A
# 8            Teen    0.499518        N/A
# 9    Everyone 10+    2.844399        N/A
# 10     Mature 17+    0.009116        Yes
# 11     Mature 17+    1.052647         No
# 12   Everyone 10+    2.436995         No
# 13       Everyone    3.007898        Yes
# 14           Teen    1.800000        N/A
# 15           Teen    0.260509        N/A
# 16           Teen    1.951501        N/A
# 17       Everyone    2.186241        N/A
# 18   Everyone 10+    0.705101        Yes
# 19       Everyone    1.314072         No
# 20       Everyone    1.140962        Yes
# 21       Everyone    1.849994        Yes
# 22       Everyone    2.695213         No
# 23   Everyone 10+    0.098951        N/A
# 24     Mature 17+    0.000000         No
# 25           Teen    1.560063        N/A
# 26   Everyone 10+    1.908851         No
# 27   Everyone 10+    0.556964         No
# 28   Everyone 10+    1.563536        N/A
# 29     Mature 17+    2.053732        N/A

# %%
df.to_excel('PGD_Google_APP_Data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-67-5ff0b0affb68> in <module>
# ----> 1 df.to_excel('PGD_Google_APP_Data.xlsx',engine='xlsxwriter')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
#    2190             excel_writer,
#    2191             sheet_name=sheet_name,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     813             # abstract class 'ExcelWriter' with abstract attributes 'engine',
#     814             # 'save', 'supported_extensions' and 'write_cells'  [abstract]
# --> 815             writer = ExcelWriter(  # type: ignore[abstract]
#     816                 writer, engine=engine, storage_options=storage_options
#     817             )
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, **engine_kwargs)
#     180             raise ValueError("Append mode is not supported with xlsxwriter!")
#     181
# --> 182         super().__init__(
#     183             path,
#     184             engine=engine,
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, **engine_kwargs)
#     808         self.handles = IOHandles(cast(Buffer, path), compression={"copression": None})
#     809         if not isinstance(path, ExcelWriter):
# --> 810             self.handles = get_handle(
#     811                 path, mode, storage_options=storage_options, is_text=False
#     812             )
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# PermissionError: [Errno 13] Permission denied: 'PGD_Google_APP_Data.xlsx'

# %%
df.to_csv('PGD_Google_APP_Data.csv')
